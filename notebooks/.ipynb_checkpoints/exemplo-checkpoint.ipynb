# %%
# !pip install psycopg2==2.9.4
# !pip install pyarrow

import pandas as pd
import sqlalchemy
from bokeh.io import output_notebook, show
output_notebook()
# Out:
# Requirement already satisfied: psycopg2==2.9.4 in /opt/conda/lib/python3.10/site-packages (2.9.4)
# Requirement already satisfied: pyarrow in /opt/conda/lib/python3.10/site-packages (9.0.0)
# Requirement already satisfied: numpy>=1.16.6 in /opt/conda/lib/python3.10/site-packages (from pyarrow) (1.23.3)
# <div class="bk-root">
#         <a href="https://bokeh.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="1001">Loading BokehJS ...</span>
#     </div>

# %%
engine = sqlalchemy.create_engine(
    "postgresql://postgres:postgres@postgres:5432/soberana_data"
)

# %%
with engine.connect() as conn:
    avg_online_members_by_hour_weekday = pd.read_sql("select * from active_discord_members_by_hour", con=conn
)

# %%
avg_online_members_by_hour_weekday.head(10)
# Out:
#   week_name                      hour  avg_members
# 0     Sexta 2022-10-14 23:00:00+00:00         6225
# 1    Sábado 2022-10-15 20:00:00+00:00         5321
# 2    Sábado 2022-10-15 09:00:00+00:00         2900
# 3    Sábado 2022-10-15 19:00:00+00:00         4920
# 4    Sábado 2022-10-15 18:00:00+00:00         4331
# 5    Sábado 2022-10-15 02:00:00+00:00         6616
# 6    Sábado 2022-10-15 13:00:00+00:00         1879
# 7    Sábado 2022-10-15 06:00:00+00:00         5817
# 8    Sábado 2022-10-15 07:00:00+00:00         4519
# 9    Sábado 2022-10-15 04:00:00+00:00         6886
