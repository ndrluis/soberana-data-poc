# %%
# !pip install psycopg2==2.9.4
# !pip install pyarrow

import pandas as pd
import sqlalchemy
# Out:
# Requirement already satisfied: psycopg2==2.9.4 in /opt/conda/lib/python3.10/site-packages (2.9.4)
# Collecting pyarrow
#   Downloading pyarrow-9.0.0-cp310-cp310-manylinux_2_17_aarch64.manylinux2014_aarch64.whl (32.9 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 32.9/32.9 MB 28.3 MB/s eta 0:00:0000:0100:01
# Requirement already satisfied: numpy>=1.16.6 in /opt/conda/lib/python3.10/site-packages (from pyarrow) (1.23.3)
# Installing collected packages: pyarrow
# Successfully installed pyarrow-9.0.0

# %%
engine = sqlalchemy.create_engine(
    "postgresql://postgres:postgres@postgres:5432/soberana_data"
)

conn = engine.connect()

# %%
df = pd.read_parquet("../extract/data/discord.parquet")
df
# Out:
#          code  type expires_at  approximate_member_count  \
# 0  UQZpTQbCT4     0       None                     30291
#
#    approximate_presence_count            guild.id           guild.name  \
# 0                        6214  828778305691844609  Comunidade Soberana
#
#                        guild.splash                      guild.banner  \
# 0  ed5c5cf789e4dafabf6a216cb9ef83a2  0fc2073ad902ddc4eb241b7b1ed22541
#
#                                    guild.description  ...          channel.id  \
# 0  A Soberana é um coletivo marxista-leninista qu...  ...  828778306160820265
#
#     channel.name  channel.type         inviter.id  inviter.username  \
# 0  ☭│boas-vindas             0  88361597508009984          Azhariel
#
#                      inviter.avatar  inviter.avatar_decoration  \
# 0  2ec2d95145b0e41f723487686387d762                       None
#
#   inviter.discriminator inviter.public_flags                  _started_at
# 0                  9860                  128  2022-10-14T20:21:31.694276Z
#
# [1 rows x 29 columns]

# %%
df.to_parquet("../extract/data/discord.parquet", compression="gzip")
